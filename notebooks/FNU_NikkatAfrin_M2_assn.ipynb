# %% [markdown]
# # DAV 5400 Module 2 Assignment
#
#
# ## Introduction:
#
# This assignment is the continuation of the work that started in module 1 with some additional insights, delving deeper and working on new concepts like 'list Comprehensions' and 'functions.'
#
# In Module 1, we created six separate lists that represent different attributes of hospital patients. These lists include Diagnosis, Age, Gender, Type of chest pain, blood pressure reading, and cholesterol level.
#
# ## Reading the M1_Data.txt:
#
# For this task, we need to read the M1_Data40.txt file, which we did in Module 1.
#
# I imported the csv and used with open() to open the file.
# Then to read the file I used a reader object and for loop to read and print all the contents of the file.

# %%
import csv 
with open('C:/Users/nikka/Downloads/M1_Data.txt') as csvfile:
    readCSV = csv.reader(csvfile)
    for row in readCSV:
        # print each row as read by the csv.reader function
        print(row)
# Out:
# ['FALSE', '63', 'MALE', 'TYPICAL_ANGINA', '145', '233']
# ['TRUE', '67', 'MALE', 'ASYMPTOMATIC', '160', '286']
# ['TRUE', '67', 'MALE', 'ASYMPTOMATIC', '120', '229']
# ['FALSE', '37', 'MALE', 'NON_ANGINAL', '130', '250']
# ['FALSE', '41', 'FEMALE', 'ATYPICAL_ANGINA', '130', '204']
# ['FALSE', '56', 'MALE', 'ATYPICAL_ANGINA', '120', '236']
# ['TRUE', '62', 'FEMALE', 'ASYMPTOMATIC', '140', '268']
# ['FALSE', '57', 'FEMALE', 'ASYMPTOMATIC', '120', '354']
# ['TRUE', '63', 'MALE', 'ASYMPTOMATIC', '130', '254']
# ['TRUE', '53', 'MALE', 'ASYMPTOMATIC', '140', '203']
# ['FALSE', '57', 'MALE', 'ASYMPTOMATIC', '140', '192']
# ['FALSE', '56', 'FEMALE', 'ATYPICAL_ANGINA', '140', '294']
# ['TRUE', '56', 'MALE', 'NON_ANGINAL', '130', '256']
# ['FALSE', '44', 'MALE', 'ATYPICAL_ANGINA', '120', '263']
# ['FALSE', '52', 'MALE', 'NON_ANGINAL', '172', '199']
# ['FALSE', '57', 'MALE', 'NON_ANGINAL', '150', '168']
# ['TRUE', '48', 'MALE', 'ATYPICAL_ANGINA', '110', '229']
# ...

# %% [markdown]
# ## Initializing lists for different attributes:
#
# This code accomplishes the following:
#
# 1. Open the "M1_Data.txt" file using the csv library module.
# 2. Creates six lists (diagnosis, ages, genders, chest_pains, blood_pressure, cholesterol) to store different attributes of the hospital patient data.
# 3. Iterates through each row of the CSV file to do this I used for loop.
# 4. Extracting and appending data to the respective lists for this is created empty lists and then appended them using append function.

# %%
with open('C:/Users/nikka/Downloads/M1_Data.txt') as csvfile:
    readCSV = csv.reader(csvfile)
    diagnosis, ages, genders, chest_pains, blood_pressure, cholesterol = ([] for row in range(6))
    for row1 in readCSV:
        diagnosis.append(row1[0])
        ages.append(int(row1[1]))
        genders.append(row1[2])
        chest_pains.append(row1[3])
        blood_pressure.append(int(row1[4]))
        cholesterol.append(int(row1[5]))

# %% [markdown]
# ## List Comprehensions
#
#
# ### Task 1:
# Your first task is to find the list index values of each hospital patient having a “blood pressure” reading
# that is greater than 140. However, you are required to do this using a list comprehension instead of a basic for or
# while loop. The list comprehension should create a new list containing your result. Be sure to print your results to
# the screen
#
# ### Solution:
#
# #### 1. Index:
# - This is the list to store the index value of the patient having blood pressure reading greater than 140.
# - To extract the index value of the patients i used list comprehension, where I used 'for loop' and 'if conditional statement'.
# - In this we printed 'i' value as it is storing the index value of the blood_pressure list which met the condition.
#
# #### 2. BP:
# - This is the list to store the blood pressure value of the patient having blood pressure reading greater than 140.
# - To extract the bp value of the patients i used list comprehension, where I used 'for loop' and 'if conditional statement'.
# - In this we printed 'row' value as it is storing the bp value of the blood_pressure list which met the if conditional statement.

# %%
index=[i for i,row in enumerate(blood_pressure) if row>140]
bp=[row for i,row in enumerate(blood_pressure) if row>140 ]
print(index)
bp
# Out:
# [0, 1, 14, 15, 21, 27, 28, 37, 39]
# [145, 160, 172, 150, 150, 150, 150, 150, 150]

# %% [markdown]
# ### Task 2:
#
# Your second task is to find the "pain type" value for each hospital patient having a "blood pressure" value
# that is greater than 140 using a list comprehension instead of a basic for or while loop. The list comprehension
# should create a new list containing your findings. Be sure to print your results to the screen.
#
# ### Solution:
#
# #### 1. chest_pain:
#
# - This is the list to store the chest_pain data of the patient having blood pressure reading greater than 140.
# - To extract the chest_pain data of the patients i used list comprehension, where I used 'for loop statement.
# - In this we printed 'chest_pains[i]' elements of the chest_pain list.

# %%
chest_pain=[chest_pains[i] for i in index]
chest_pain
# Out:
# ['TYPICAL_ANGINA',
#  'ASYMPTOMATIC',
#  'NON_ANGINAL',
#  'NON_ANGINAL',
#  'TYPICAL_ANGINA',
#  'TYPICAL_ANGINA',
#  'ASYMPTOMATIC',
#  'ASYMPTOMATIC',
#  'NON_ANGINAL']

# %% [markdown]
# ### Task 3:
# Your third task is to find the index value for each hospital patient having a “gender” value of "FEMALE"
# and a “pain type” value that is not "ASYMPTOMATIC using a list comprehension. The list comprehension should
# create a new list containing your findings. Be sure to print your results to the screen.
#
# ### Solution:
#
# #### 1.ind:
# - This is the list to store the index value of the patient having 'gender' as 'female' and 'pain type' value that is not 'Asymptomatic'.
# - To extract the index value of the patients i used list comprehension, where I used 'for loop' and 'if conditional statement'.
# - In this we printed 'i' value as it is storing the index value of the genders list which met the conditional statement.

# %%
ind=[i for i,row in enumerate(genders) if row=='FEMALE'and chest_pains[i]!="ASYMPTOMATIC"]
ind
# Out:
# [4, 11, 18, 21, 25, 26, 27, 30]

# %% [markdown]
# ### Task 4:
# Nested List Comprehensions
# Consider the following list of lists:
# nlist = [ [2112, ‘YYZ’, 81], [1, 2, 3], [‘A’, ‘B’, ‘C’], [4, 5], [‘D’, ‘E’] ]
# If we wanted to extract each individual element of the component lists contained within nlist and add them to a new
# list, we could use a nested for loop similar to this:
#
# flist = []
# for x in nlist:
# for y in x:
# flist.append(y)
# print(flist)
#
# For your fourth task, implement this same logic using a list comprehension. Apply your list
# comprehension to the nlist list of lists shown above. Be sure to print your newly created list to the screen
#
# ### Solution:
#
# #### nlist:
# - This is the nlist which is basically a nested list, whcih have five different list embeded in it.
# - I created a flist and using the 'List Comprehensions', I stored all the elements of the nested list into the flist.
# - TO do this I used a 'nested for loop' one loop for extracting the each list element of the n list and another loop for extracting the elements within the list elements.
# - Then we printed the 'y' value which is basically the element value of every nested list.

# %%
nlist = [ [2112, 'YYZ', 81], [1, 2, 3], ['A', 'B', 'C'], [4, 5], ['D', 'E'] ]
flist = [y for x in nlist for y in x]
flist
# Out:
# [2112, 'YYZ', 81, 1, 2, 3, 'A', 'B', 'C', 4, 5, 'D', 'E']

# %% [markdown]
# ####  This is the code given by the professor, I simply run this to compare the two outputs.

# %%
nlist = [ [2112, 'YYZ', 81], [1, 2, 3], ['A', 'B', 'C'], [4, 5], ['D', 'E'] ]
flist = []
for x in nlist:
    for y in x:
        flist.append(y)
print(flist)
# Out:
# [2112, 'YYZ', 81, 1, 2, 3, 'A', 'B', 'C', 4, 5, 'D', 'E']

# %% [markdown]
# ### Task 5:
#
# #### Write a Function That Converts a List to a Dict Object
#
# Your fifth task is to create a user defined function that accepts as input one of the six hospital patient
# attribute lists as well as an integer value and returns a Python dict object. Remember: a Python dict object is
# comprised of ‘key/value’ pairs. The integer value accepted as a parameter by your function will represent the exact
# number of items you are to use from the list for purposes of creating the new dict object. So for example, if your
# function was defined as:
#
# def makedict(mylist, x):
# newdict = {}
# #your code goes here
# return(newdict)
#
# you would take the first x items from mylist to create the new dict object. The key values you assign to the elements of
# the dict object should all be comprised of a combination of the word ‘KEY’ and the alphanumeric representation of the
# index value corresponding to the location of the item in the mylist object. So if you had 3 dict elements in total, the key
# values for those elements would be (‘KEY0’, ‘KEY1’, ‘KEY2’). If we apply this concept to the first four elements of our
# “type of chest pain” list we’d have a dict object that looks like this:
#
# First four elements of the type of chest pain list:
# ['TYPICAL_ANGINA', 'ASYMPTOMATIC', 'ASYMPTOMATIC', 'NON_ANGINAL']
#
# New dict Object:
# {‘KEY0’ : ‘TYPICAL_ANGINA’, ‘KEY1’: ‘ASYMPTOMATIC’, ‘KEY2’: ‘ASYMPTOMATIC’, ‘KEY3’:‘'NON_ANGINAL’}
#
# Be sure to check that the integer value passed into your function does not exceed the length of the list parameter!
#
# ### Solution:
#
# #### 1. def makedict(mylist,x):
# - This is the user defined function which take two argumented integer values as mylist and x.
# - In this function the functioned is called and argumented value is sent during the invokation of the function.
#
# #### 2. newdict:
# - This is the dictonary object and we used the dict comprehension to get our desired output.
# - In this we used f'key{i}' as our 'key' to our dictionary element values, which is a formatting string which help us to embed expressions inside the strings.
# - Next is the 'Value' where we print the value of the particular list the user desired.
# - I also used for loop along with the if condition statement for the execution process.
#
# #### 3. return(newdict):
# - This statement is used to return the function output.

# %%
def makedict(mylist, x):
    newdict = {f'key{i}':value for i,value in enumerate (mylist) if i<x}
    # your code goes here
''''    for i,value in enumerate (mylist):
            key=f'key{i}'
            newdict[key]=value '''

    return(newdict)

# %% [markdown]
# Below is the input statement which I used to input from the user of his desired list.

# %%
dict_input= int(input(('Select the list you want based on 0 to 5 numbers : \n 0-diagnosis \n 1-ages \n 2-genders \n 3-chest_pains \n 4-blood_pressure \n 5-cholesterol \n')))
# Out:
# Select the list you want based on 0 to 5 numbers :
#  0-diagnosis
#  1-ages
#  2-genders
#  3-chest_pains
#  4-blood_pressure
#  5-cholesterol
# 3

# %% [markdown]
# #### 1.big_list:
# - This is the super list which have all the remaining lists embeded into it.
# - The user input which i got from the dict_input I am using that for choosing particular list of data.
#
# #### 2. y input:
# - This is the variable im using to take the input from the user to ask the number of elements they want it to print.
#
# #### 3. makedict(big_list[dict_input],y):
# - This is the function call/ fucntion invoke and here the list and the y value is sent to the defined function for the execution process.

# %%
big_list=[diagnosis,ages,genders,chest_pains,blood_pressure,cholesterol]
y=int(input('The number of items we want from the list is : '))
makedict(big_list[dict_input],y)
# Out:
# The number of items we want from the list is : 10
# {'key0': 'TYPICAL_ANGINA',
#  'key1': 'ASYMPTOMATIC',
#  'key2': 'ASYMPTOMATIC',
#  'key3': 'NON_ANGINAL',
#  'key4': 'ATYPICAL_ANGINA',
#  'key5': 'ATYPICAL_ANGINA',
#  'key6': 'ASYMPTOMATIC',
#  'key7': 'ASYMPTOMATIC',
#  'key8': 'ASYMPTOMATIC',
#  'key9': 'ASYMPTOMATIC'}

# %% [markdown]
# ### Task 6:
#
# Using Your New Function
# Now that you have your reusable user-defined function, use it to create two new dict objects containing
# the first twelve elements of the ‘Age’ and ‘Diagnosis’ lists, respectively. Then, use these dict objects to tell us the
# Diagnosis and Age of the hospital patient identified by the ‘KEY10’ key value.
#
# ### Solution:
#
# #### 1. age_dict:
# - This is the dictonary which will store the values of the age list.
# - In this I particulary sent the values statically rather than giving dynamically as an input format.
# - And in the question it is asked 12 elements so I sent the 12 integer value instead of y.
# - Then i printed the dictonary.

# %%
age_dict=makedict(big_list[1],12)
age_dict
# Out:
# {'key0': 63,
#  'key1': 67,
#  'key2': 67,
#  'key3': 37,
#  'key4': 41,
#  'key5': 56,
#  'key6': 62,
#  'key7': 57,
#  'key8': 63,
#  'key9': 53,
#  'key10': 57,
#  'key11': 56}

# %% [markdown]
# #### 2. diagnosis_dict:
# - This is the dictonary which will store the values of the big_list[0] list which will ultimately invoke the diagnosis list.
# - In this I particulary sent the values statically rather than giving dynamically rather than an input format.
# - And in the question it is asked 12 elements so I sent the 12 integer value instead of y.
# - Then i printed the dictonary.

# %%
diagnosis_dict=makedict(big_list[0],12)
diagnosis_dict
# Out:
# {'key0': 'FALSE',
#  'key1': 'TRUE',
#  'key2': 'TRUE',
#  'key3': 'FALSE',
#  'key4': 'FALSE',
#  'key5': 'FALSE',
#  'key6': 'TRUE',
#  'key7': 'FALSE',
#  'key8': 'TRUE',
#  'key9': 'TRUE',
#  'key10': 'FALSE',
#  'key11': 'FALSE'}

# %% [markdown]
# #### 3. Here the key10 value of age_dict and diagnosis_dict is asked so i directly printed them using the output print statement.

# %%
print(age_dict['key10'])
print(diagnosis_dict['key10'])
# Out:
# 57
# FALSE

# %% [markdown]
# # THANK YOU.
